# %%
#include("rw_functions.jl")
using Base.Test
include("../koi_launcher.jl","no_rw","no_plots")
# Out:
# no method include_from_node1(ASCIIString, ASCIIString, ASCIIString)
# while loading In[5], in expression starting on line 3

# %%
using PyPlot;
a = koi_launcher("koi_list.csv")
# Out:
# assertion failed: isfile(inputname)
# while loading In[4], in expression starting on line 2
#  in read_ascii at /home/mark/Dropbox/School/2014_1Spring/ASTRO_585/kepler_ttv/kepler_procedures/rw_functions.jl:3
#  in koi_launcher at /home/mark/Dropbox/School/2014_1Spring/ASTRO_585/kepler_ttv/kepler_procedures/koi_launcher.jl:41 (repeats 2 times)

# %%
include("rw_functions.jl")
# Out:
# write_lightcurve_ascii (generic function with 1 method)

# %%
data_952 = read_ascii("lightcurves/952.01.csv")
time = data_952[:,1]
flux = data_952[:,2]
orig_flux = data_952[:,3]
println(length(time))
plot(time,orig_flux,linewidth=0,marker=".",markersize=1)
plot(time,flux,color="red",marker=".",linewidth=0,markersize=1)
ylim(0.99,1.01)
#xlim(950,1150)
# Out:
# 49620
# Figure(PyObject <matplotlib.figure.Figure object at 0x7fb4d7e765c0>)
# (0.99,1.01)

# %%
data_738 = read_ascii("lightcurves/738.01.csv")
time = data_738[:,1]
flux = data_738[:,2]
orig_flux = data_738[:,3]
println(length(time))
plot(time,orig_flux,linewidth=2)
plot(time,flux,color="red")
ylim(0.997,1.004)
#xlim(950,1150)
# Out:
# 49749
# Figure(PyObject <matplotlib.figure.Figure object at 0x7fb4d8eec898>)
# (0.997,1.004)
